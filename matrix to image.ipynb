# %%
from PIL import Image
import numpy as np
# Creating the 144 X 144 NumPy Array with random values
arr = np.random.randint(255, size=(800, 500), dtype=np.uint8)
# Converting the numpy array into image
img  = Image.fromarray(arr)
# Saving the image
img.save("Image_from_array.png")
print(" The Image is saved successfully")
img.show()
# Out:
#  The Image is saved successfully

# %%
#displaying current working img

import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\image processing'

# %%
image1 = Image.open("earth.jpg")

image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x27F7F6D7760>

# %%
image1.show()

# %%
image1.save('100.png')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '03 01 2023.ipynb',
#  '10 1 2023.ipynb',
#  '100.png',
#  '12 01 2023.ipynb',
#  '12.png',
#  '1234.jpg',
#  '2.jfif',
#  '22.jpg',
#  '22.png',
#  '23.jpg',
#  '29 12 2022.ipynb',
#  '3.jpg',
#  '31.jpg',
#  '4.jpg',
#  '7.jpg',
#  'burred.jpg',
#  'burred1.jpg',
#  'butterfly.png',
#  'cat.png',
#  'cat1.jpg',
#  'cat2.jpg',
#  'cat3.jpg',
#  'cat4.jpg',
#  'cat_inpaint.png',
#  'chintu.jpg',
#  'circle_text_inpainted_ns.png',
#  'circle_text_inpainted_telea.png',
#  'circle_text_mask.png',
#  'circle_text_threshold.png',
#  'crop.png',
#  'dice.png',
#  'dice1.png',
#  'dice2.jpg',
#  'earth.jpg',
#  'earth3.jpg',
#  'face.jpg',
#  'food.jpg',
#  'food1.jpg',
#  'g.jpg',
#  'galaxy.jpg',
#  'galaxyy.jpg',
#  'gfg_dummy_pic.png',
#  'globe.jpg',
#  'horse.jpg',
#  'hy.png',
#  'hy2.png',
#  'image2.ipynb',
#  'image3.ipynb',
#  'image4(22 12 2022).ipynb',
#  'Image_from_array.png',
#  'image_text.jpg',
#  'img manipulation.ipynb',
#  'img.png',
#  'logo1.jpg',
#  'logoo1.png',
#  'mass.png',
#  'matrix to image.ipynb',
#  'mintu.jpg',
#  'montage.png',
#  'nature.jpg',
#  'new.png',
#  'noisy.png',
#  'panda.jpg',
#  'panda1.jpg',
#  'pdf.png',
#  'pic1.jpg',
#  'purple.png',
#  'quote.jpg',
#  'quote1.jpg',
#  'reduce.jpg',
#  's.jpg',
#  's1.jpg',
#  'sharpness,flipping, cropping.ipynb',
#  'text.ipynb',
#  'vary.jpg',
#  'watermark.jpg',
#  'yolo.jpg',
#  'yolo2.jpg',
#  'yolo3.jpg']

# %%
#creating folder
os.mkdir('sandhya')

# %%
#storing an images to pdf
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.save("sandhya/{}.pdf".format(fn))

# %%
#displaying jpg images
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        print(fn, "&", fext)
# Out:
# 1234 & .jpg
# 22 & .jpg
# 23 & .jpg
# 3 & .jpg
# 31 & .jpg
# 4 & .jpg
# 7 & .jpg
# burred & .jpg
# burred1 & .jpg
# cat1 & .jpg
# cat2 & .jpg
# cat3 & .jpg
# cat4 & .jpg
# chintu & .jpg
# dice2 & .jpg
# earth & .jpg
# earth3 & .jpg
# face & .jpg
# food & .jpg
# food1 & .jpg
# g & .jpg
# galaxy & .jpg
# galaxyy & .jpg
# globe & .jpg
# horse & .jpg
# image_text & .jpg
# logo1 & .jpg
# mintu & .jpg
# nature & .jpg
# panda & .jpg
# panda1 & .jpg
# pic1 & .jpg
# quote & .jpg
# quote1 & .jpg
# reduce & .jpg
# s & .jpg
# s1 & .jpg
# vary & .jpg
# watermark & .jpg
# yolo & .jpg
# yolo3 & .jpg

# %%
#displaying jpg images
for f in os.listdir("."):
    if f.endswith(".jpg"):
        print(f)
# Out:
# 1234.jpg
# 22.jpg
# 23.jpg
# 3.jpg
# 31.jpg
# 4.jpg
# 7.jpg
# burred.jpg
# burred1.jpg
# cat1.jpg
# cat2.jpg
# cat3.jpg
# cat4.jpg
# chintu.jpg
# dice2.jpg
# earth.jpg
# earth3.jpg
# face.jpg
# food.jpg
# food1.jpg
# g.jpg
# galaxy.jpg
# galaxyy.jpg
# globe.jpg
# horse.jpg
# image_text.jpg
# logo1.jpg
# mintu.jpg
# nature.jpg
# panda.jpg
# panda1.jpg
# pic1.jpg
# quote.jpg
# quote1.jpg
# reduce.jpg
# s.jpg
# s1.jpg
# vary.jpg
# watermark.jpg
# yolo.jpg
# yolo3.jpg

# %%
# Creating new multiple Directories using OS library
os.makedirs('resize//small')
os.makedirs('resize//tiny')

# %%
#We can resize the images in the size as well as the aspect ratio we want. We will make one more folder inside the base folder we are working on, called “resize” and inside that folder, we will have two more folders. I want to have photos for two different purposes, one for posting as postcards on the webpage, and another for smaller thumbnails of those postcards. So I will save them in separate folders. Let’s name the folders “small” and “tiny”. .thumbnail() is the method used to change the size here, and the argument is a tuple of the size we want.
size_small = (600,600) # small images of 600 X 600 pixels
size_tiny = (200,200)  # tiny images of 200 X 200 pixels
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.thumbnail(size_small)
        i.save("resize/small/{}_small{}".format(fn, fext))
        i.thumbnail(size_tiny)
        i.save("resize/tiny/{}_tiny{}".format(fn, fext))

# %%
os.mkdir('rotate')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5788/469304631.py in <module>
# ----> 1 os.mkdir('rotate')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'rotate'

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.rotate(90)
        im.save("rotate/{}_rot.{}".format(fn, fext))
