# %%
import cv2
image = cv2.imread("22.jpg")
cv2.imshow('images',image)
cv2.imwrite("D:\img.jpg", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread("22.jpg", 0)
cv2.imshow('images',image)
cv2.imwrite("D:/img.jpg", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread("C:/Users/User/Downloads/images/23.jpg")
cv2.imshow('images',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import Image


x = "23.jpg"
img = Image.open(x)


width = img.width
height = img.height


print("The height of the image is: ", height)
print("The width of the image is: ", width)
# Out:
# The height of the image is:  225
# The width of the image is:  225

# %%
import numpy

image = cv2.imread("22.jpg")
print("no of channels is:"+str(image.ndim))
print("no of channels is:", image.shape)
cv2.imshow('images',image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# no of channels is:3
# no of channels is: (219, 230, 3)

# %%
from PIL import Image
filepath = "31.jpg"
im= Image.open(filepath)
new_im = im.resize((300, 200))
new_im
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x1C90A1ADF10>

# %%
import matplotlib .image as image
img  = image.imread("22.jpg")
print("the shape of image:", img.shape)
print("the image as array is ")
print(img)
# Out:
# the shape of image: (219, 230, 3)
# the image as array is
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
import cv2

img  = cv2.imread("22.jpg",0)
ret, bw_img = cv2.threshold(img , 127, 225, cv2.THRESH_BINARY)
bw = cv2.threshold(img ,225,127, cv2.THRESH_BINARY)
cv2.imshow("Binary", bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
imgi = cv2.imread("31.jpg",1)
B, G, R = cv2.split(imgi)
print(B)
print(G)
print(R)
# Out:
# [[161 182 183 ...  52  49  46]
#  [131 135 138 ...  59  57  54]
#  [ 98  85  97 ...  63  62  58]
#  ...
#  [ 40  14   9 ... 145 145 145]
#  [ 47  28  29 ... 143 144 144]
#  [ 45  36  44 ... 145 145 145]]
# [[188 206 194 ... 127 124 122]
#  [158 159 149 ... 132 128 125]
#  [125 109 108 ... 131 128 124]
#  ...
#  [ 68  42  36 ... 108 108 108]
#  [ 73  54  53 ... 106 107 107]
#  [ 69  60  67 ... 108 108 108]]
# [[202 218 208 ... 149 146 141]
#  [172 171 163 ... 152 148 145]
#  [139 121 122 ... 150 146 142]
#  ...
#  [ 92  66  57 ...  82  82  82]
#  [ 97  78  75 ...  80  81  81]
#  [ 91  82  89 ...  82  82  82]]

# %%
imgi = cv2.imread("31.jpg",1)
cv2.imshow('Original',imgi)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('Blue',B)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('Red',R)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('Green',G)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
im  = cv2.imread("31.jpg")
new_im = im.resize((400, 200))
ar = 1*(img.shape[1]/img.shape[0])
print("aspect ratio:")
print(ar)
# Out:
# aspect ratio:
# 1.0502283105022832
